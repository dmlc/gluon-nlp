# %% [markdown]
# # Evaluating Pre-trained Word Embeddings - Extended results

# %% [markdown]
# This notebook contains the extended results on word embeddings evaluation.
# Please see the `word_embeddings_evaluation.ipynb` notebook in the `docs/examples` directory for aggregated results.

# %%
import pandas as pd
pd.options.display.max_rows = 999

df = pd.read_table("results-vocablimit.csv", header=None, names=[
    "evaluation_type", "dataset", "kwargs", "embedding_name",
    "embedding_source", "evaluation", "value", "num_samples"
])


def get_multi_index_highlighter(levels=[0, 1]):
    '''Return a pandas DataFrame highlighter function for MultiIndices.
    
    The multi_index_highlighter returned will operate independently
    on all subsets of rows per unique index along the specified levels.
    
    '''
    def multi_index_highlighter(s):
        colors = []
        for key, _ in s.groupby(level=levels):
            is_max = s.loc[key] == s.loc[key].max()
            colors += ['background-color: yellow' if v else '' for v in is_max]
        return colors
    return multi_index_highlighter

# %% [markdown]
# ## Similarity task
# We can see that the performance varies between the different embeddings on the different datasests.
#
# Please see the [API page](http://gluon-nlp.mxnet.io/api/data.html#word-embedding-evaluation-datasets) for more information about the respective datasets.

# %%
dfs = df[~df["dataset"].isin(["BiggerAnalogyTestSet", "GoogleAnalogyTestSet"])].drop(["evaluation_type", "evaluation", "num_samples"], axis=1)
dfs = dfs[dfs["embedding_source"].isin([
    "glove.42B.300d",
    "glove.6B.100d",
    "glove.6B.200d",
    "glove.6B.300d",
    "glove.6B.50d",
    "glove.840B.300d",
    "glove.twitter.27B.100d",
    "glove.twitter.27B.200d",
    "glove.twitter.27B.25d",
    "glove.twitter.27B.50d",
    "wiki.en",
    "wiki.simple",
    "crawl-300d-2M",
    "wiki-news-300d-1M"
])]

dfsi = dfs.set_index(["dataset", "kwargs", "embedding_name", "embedding_source"])
dfsi = dfsi.sort_values(by='value', ascending=False).sort_index(level=[0,1], sort_remaining=False)
dfsi.style.apply(get_multi_index_highlighter(levels=[0,1]))
# To get the html representation of the rendered table, call `render()` on the Styler
# Out:
# <style  type="text/css" >
#     #T_27a24cce_4771_11e8_885e_16909875b9derow0_col0 {
#             background-color:  yellow;
#         }    #T_27a24cce_4771_11e8_885e_16909875b9derow14_col0 {
#             background-color:  yellow;
#         }    #T_27a24cce_4771_11e8_885e_16909875b9derow28_col0 {
#             background-color:  yellow;
#         }    #T_27a24cce_4771_11e8_885e_16909875b9derow42_col0 {
#             background-color:  yellow;
#         }    #T_27a24cce_4771_11e8_885e_16909875b9derow56_col0 {
#             background-color:  yellow;
#         }    #T_27a24cce_4771_11e8_885e_16909875b9derow70_col0 {
#             background-color:  yellow;
#         }    #T_27a24cce_4771_11e8_885e_16909875b9derow84_col0 {
#             background-color:  yellow;
#         }    #T_27a24cce_4771_11e8_885e_16909875b9derow98_col0 {
#             background-color:  yellow;
#         }    #T_27a24cce_4771_11e8_885e_16909875b9derow112_col0 {
#             background-color:  yellow;
#         }    #T_27a24cce_4771_11e8_885e_16909875b9derow126_col0 {
#             background-color:  yellow;
#         }    #T_27a24cce_4771_11e8_885e_16909875b9derow140_col0 {
#             background-color:  yellow;
#         }    #T_27a24cce_4771_11e8_885e_16909875b9derow154_col0 {
#             background-color:  yellow;
#         }    #T_27a24cce_4771_11e8_885e_16909875b9derow168_col0 {
#             background-color:  yellow;
#         }    #T_27a24cce_4771_11e8_885e_16909875b9derow182_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_27a24cce_4771_11e8_885e_16909875b9de" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >dataset</th>
#         <th class="index_name level1" >kwargs</th>
#         <th class="index_name level2" >embedding_name</th>
#         <th class="index_name level3" >embedding_source</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel0_row0" class="row_heading level0 row0" rowspan=14>BakerVerb143</th>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel1_row0" class="row_heading level1 row0" rowspan=14>{}</th>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel2_row0" class="row_heading level2 row0" rowspan=4>fasttext</th>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row0" class="row_heading level3 row0" >wiki-news-300d-1M</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow0_col0" class="data row0 col0" >0.462748</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row1" class="row_heading level3 row1" >crawl-300d-2M</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow1_col0" class="data row1 col0" >0.447303</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row2" class="row_heading level3 row2" >wiki.en</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow2_col0" class="data row2 col0" >0.397307</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row3" class="row_heading level3 row3" >wiki.simple</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow3_col0" class="data row3 col0" >0.343885</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel2_row4" class="row_heading level2 row4" rowspan=10>glove</th>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row4" class="row_heading level3 row4" >glove.840B.300d</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow4_col0" class="data row4 col0" >0.341463</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row5" class="row_heading level3 row5" >glove.42B.300d</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow5_col0" class="data row5 col0" >0.327522</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row6" class="row_heading level3 row6" >glove.6B.300d</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow6_col0" class="data row6 col0" >0.305143</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row7" class="row_heading level3 row7" >glove.6B.100d</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow7_col0" class="data row7 col0" >0.302301</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row8" class="row_heading level3 row8" >glove.6B.200d</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow8_col0" class="data row8 col0" >0.284473</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row9" class="row_heading level3 row9" >glove.6B.50d</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow9_col0" class="data row9 col0" >0.250317</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row10" class="row_heading level3 row10" >glove.twitter.27B.200d</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow10_col0" class="data row10 col0" >0.199709</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row11" class="row_heading level3 row11" >glove.twitter.27B.100d</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow11_col0" class="data row11 col0" >0.184107</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row12" class="row_heading level3 row12" >glove.twitter.27B.25d</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow12_col0" class="data row12 col0" >0.162098</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row13" class="row_heading level3 row13" >glove.twitter.27B.50d</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow13_col0" class="data row13 col0" >0.155813</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel0_row14" class="row_heading level0 row14" rowspan=42>MEN</th>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel1_row14" class="row_heading level1 row14" rowspan=14>{"segment": "dev"}</th>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel2_row14" class="row_heading level2 row14" >fasttext</th>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row14" class="row_heading level3 row14" >crawl-300d-2M</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow14_col0" class="data row14 col0" >0.835428</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel2_row15" class="row_heading level2 row15" >glove</th>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row15" class="row_heading level3 row15" >glove.840B.300d</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow15_col0" class="data row15 col0" >0.803037</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel2_row16" class="row_heading level2 row16" rowspan=2>fasttext</th>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row16" class="row_heading level3 row16" >wiki-news-300d-1M</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow16_col0" class="data row16 col0" >0.791102</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row17" class="row_heading level3 row17" >wiki.en</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow17_col0" class="data row17 col0" >0.76182</td>
#     </tr>    <tr>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel2_row18" class="row_heading level2 row18" rowspan=2>glove</th>
#         <th id="T_27a24cce_4771_11e8_885e_16909875b9delevel3_row18" class="row_heading level3 row18" >glove.6B.300d</th>
#         <td id="T_27a24cce_4771_11e8_885e_16909875b9derow18_col0" class="data row18 col0" >0.735006</td>
#     </tr>    <tr>

# %% [markdown]
# ## Analogy task
# For the analogy task, we report the results per category in the dataset.
# Note that the analogy task is a open vocabulary task: Given a query of 3 words, we ask the model to select a 4th word from the whole vocabulary. Different pre-trained embeddings have vocabularies of different size. In general the vocabulary of embeddings pretrained on more tokens (indicated by a bigger number before the **B** in the embedding source name) include more tokens in their vocabulary. While training embeddings on more tokens improves their quality, the larger vocabulary also makes the analogy task harder.
#
# In this experiment **all results are reported with reducing the vocabulary to the 300k most frequent tokens**. Questions containing Out Of Vocabulary words are ignored.
#
# ### Google Analogy Test Set
# We first display the results on the **Google Analogy Test Set**.
#
# - Mikolov, T., Chen, K., Corrado, G., & Dean, J. (2013). Efficient
#   estimation of word representations in vector space. In Proceedings of
#   the International Conference on Learning Representations (ICLR).
#
# The Google Analogy Test Set contains the following categories.
# All analogy questions per category follow the pattern specified by the category name.

# %%
import json
pd.Series(df[df["dataset"] == "GoogleAnalogyTestSet"]["kwargs"].unique()).apply(json.loads).apply(lambda x: x['category'])
# Out:
# 0        capital-common-countries
# 1                   capital-world
# 2                        currency
# 3                   city-in-state
# 4                          family
# 5       gram1-adjective-to-adverb
# 6                  gram2-opposite
# 7               gram3-comparative
# 8               gram4-superlative
# 9        gram5-present-participle
# 10    gram6-nationality-adjective
# 11               gram7-past-tense
# 12                   gram8-plural
# 13             gram9-plural-verbs
# dtype: object

# %% [markdown]
# We first load the results.

# %% [markdown]
# We now present the table of performances that the different embeddings achieved on the different categories of the dataset. You may find that the performance between categories varies widely and that different embeddings perform best on different categories. This is due to the different training objectives and training datasets used, inducing different properties.

# %%
dfa_google = df[df["dataset"] == "GoogleAnalogyTestSet"].drop(["evaluation_type", "num_samples", "dataset"], axis=1)
dfa_google = dfa_google[dfa_google["embedding_source"].isin([
    "glove.42B.300d",
    "glove.6B.100d",
    "glove.6B.200d",
    "glove.6B.300d",
    "glove.6B.50d",
    "glove.840B.300d",
    "glove.twitter.27B.100d",
    "glove.twitter.27B.200d",
    "glove.twitter.27B.25d",
    "glove.twitter.27B.50d",
    "wiki.en",
    "wiki.simple",
    "crawl-300d-2M",
    "wiki-news-300d-1M"
])]
dfa_google["category"] = dfa_google["kwargs"].apply(json.loads).apply(lambda x: str(x['category']))
dfa_google.drop("kwargs", axis=1, inplace=True)

# %%
dfai = dfa_google.set_index(
    ["category", "embedding_name", "embedding_source", "evaluation"])
dfai = dfai.sort_values(by='value', ascending=False).sort_index(level=[0], sort_remaining=False)
dfai.style.apply(get_multi_index_highlighter(levels=[0]))
# Out:
# <style  type="text/css" >
#     #T_27a24ccf_4771_11e8_885e_16909875b9derow0_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow28_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow56_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow84_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow112_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow140_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow168_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow169_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow196_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow224_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow252_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow280_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow308_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow336_col0 {
#             background-color:  yellow;
#         }    #T_27a24ccf_4771_11e8_885e_16909875b9derow364_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_27a24ccf_4771_11e8_885e_16909875b9de" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >category</th>
#         <th class="index_name level1" >embedding_name</th>
#         <th class="index_name level2" >embedding_source</th>
#         <th class="index_name level3" >evaluation</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel0_row0" class="row_heading level0 row0" rowspan=28>capital-common-countries</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel1_row0" class="row_heading level1 row0" >glove</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel2_row0" class="row_heading level2 row0" >glove.6B.300d</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row0" class="row_heading level3 row0" >threecosmul</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow0_col0" class="data row0 col0" >0.954545</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel1_row1" class="row_heading level1 row1" >fasttext</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel2_row1" class="row_heading level2 row1" >wiki.en</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row1" class="row_heading level3 row1" >threecosmul</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow1_col0" class="data row1 col0" >0.950593</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel1_row2" class="row_heading level1 row2" rowspan=3>glove</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel2_row2" class="row_heading level2 row2" >glove.42B.300d</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row2" class="row_heading level3 row2" >threecosadd</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow2_col0" class="data row2 col0" >0.950593</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel2_row3" class="row_heading level2 row3" >glove.6B.300d</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row3" class="row_heading level3 row3" >threecosadd</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow3_col0" class="data row3 col0" >0.948617</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel2_row4" class="row_heading level2 row4" >glove.6B.200d</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row4" class="row_heading level3 row4" >threecosadd</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow4_col0" class="data row4 col0" >0.94664</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel1_row5" class="row_heading level1 row5" >fasttext</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel2_row5" class="row_heading level2 row5" >wiki.en</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row5" class="row_heading level3 row5" >threecosadd</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow5_col0" class="data row5 col0" >0.944664</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel1_row6" class="row_heading level1 row6" rowspan=7>glove</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel2_row6" class="row_heading level2 row6" >glove.6B.200d</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row6" class="row_heading level3 row6" >threecosmul</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow6_col0" class="data row6 col0" >0.944664</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel2_row7" class="row_heading level2 row7" >glove.42B.300d</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row7" class="row_heading level3 row7" >threecosmul</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow7_col0" class="data row7 col0" >0.942688</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel2_row8" class="row_heading level2 row8" rowspan=2>glove.6B.100d</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row8" class="row_heading level3 row8" >threecosadd</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow8_col0" class="data row8 col0" >0.938735</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row9" class="row_heading level3 row9" >threecosmul</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow9_col0" class="data row9 col0" >0.922925</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel2_row10" class="row_heading level2 row10" rowspan=2>glove.840B.300d</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row10" class="row_heading level3 row10" >threecosmul</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow10_col0" class="data row10 col0" >0.820158</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row11" class="row_heading level3 row11" >threecosadd</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow11_col0" class="data row11 col0" >0.800395</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel2_row12" class="row_heading level2 row12" >glove.6B.50d</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row12" class="row_heading level3 row12" >threecosadd</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow12_col0" class="data row12 col0" >0.79249</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel1_row13" class="row_heading level1 row13" rowspan=2>fasttext</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel2_row13" class="row_heading level2 row13" rowspan=2>crawl-300d-2M</th>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row13" class="row_heading level3 row13" >threecosmul</th>
#         <td id="T_27a24ccf_4771_11e8_885e_16909875b9derow13_col0" class="data row13 col0" >0.73913</td>
#     </tr>    <tr>
#         <th id="T_27a24ccf_4771_11e8_885e_16909875b9delevel3_row14" class="row_heading level3 row14

# %% [markdown]
# ### Bigger Analogy Test Set
# We then display the results on the **Bigger Analogy Test Set (BATS)**.
#
# - Gladkova, A., Drozd, A., & Matsuoka, S. (2016). Analogy-based detection
#   of morphological and semantic relations with word embeddings: what works
#   and what doesn’t. In Proceedings of the NAACL-HLT SRW (pp. 47–54). San
#   Diego, California, June 12-17, 2016: ACL. Retrieved from
#   https://www.aclweb.org/anthology/N/N16/N16-2002.pdf
#
#
# Unlike the Google Analogy Test Set, BATS is balanced across 4 types of relations (inflectional morphology, derivational morphology, lexicographic semantics, encyclopedic semantics).
#
# We first load the results for the BATS dataset:

# %%
dfa_bats = df[df["dataset"] == "BiggerAnalogyTestSet"].drop(["evaluation_type", "num_samples", "dataset"], axis=1)
dfa_bats = dfa_bats[dfa_bats["embedding_source"].isin([
    "glove.42B.300d",
    "glove.6B.100d",
    "glove.6B.200d",
    "glove.6B.300d",
    "glove.6B.50d",
    "glove.840B.300d",
    "glove.twitter.27B.100d",
    "glove.twitter.27B.200d",
    "glove.twitter.27B.25d",
    "glove.twitter.27B.50d",
    "wiki.en",
    "wiki.simple",
    "crawl-300d-2M",
    "wiki-news-300d-1M",
])]
dfa_bats["category"] = dfa_bats["kwargs"].apply(json.loads).apply(lambda x: str(x['category']))
dfa_bats.drop("kwargs", axis=1, inplace=True)

# %%
import gluonnlp as nlp
dfa_bats["category"] = dfa_bats["category"].apply(lambda x: str(x) + ": " + nlp.data.BiggerAnalogyTestSet._categories[x])
dfai = dfa_bats.set_index(
    ["category", "embedding_name", "embedding_source", "evaluation"])
dfai = dfai.sort_values(by='value', ascending=False).sort_index(level=[0], sort_remaining=False)
dfai.style.apply(get_multi_index_highlighter(levels=[0]))
# Out:
# /home/leonard/anaconda3/envs/gluonnlp/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# <style  type="text/css" >
#     #T_29eccd56_4771_11e8_885e_16909875b9derow0_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow26_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow52_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow78_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow104_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow130_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow156_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow182_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow208_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow234_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow260_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow261_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow286_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow312_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow338_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow364_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow390_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow416_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow442_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow468_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow493_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow517_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow545_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow546_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow573_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow601_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow627_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow653_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow679_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow705_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow731_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow757_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow783_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow807_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow831_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow855_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow879_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow903_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow927_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow951_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow975_col0 {
#             background-color:  yellow;
#         }    #T_29eccd56_4771_11e8_885e_16909875b9derow999_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_29eccd56_4771_11e8_885e_16909875b9de" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >category</th>
#         <th class="index_name level1" >embedding_name</th>
#         <th class="index_name level2" >embedding_source</th>
#         <th class="index_name level3" >evaluation</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel0_row0" class="row_heading level0 row0" rowspan=26>D01: [noun+less_reg]</th>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel1_row0" class="row_heading level1 row0" rowspan=7>fasttext</th>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel2_row0" class="row_heading level2 row0" rowspan=2>wiki.simple</th>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel3_row0" class="row_heading level3 row0" >threecosmul</th>
#         <td id="T_29eccd56_4771_11e8_885e_16909875b9derow0_col0" class="data row0 col0" >0.106531</td>
#     </tr>    <tr>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel3_row1" class="row_heading level3 row1" >threecosadd</th>
#         <td id="T_29eccd56_4771_11e8_885e_16909875b9derow1_col0" class="data row1 col0" >0.0963265</td>
#     </tr>    <tr>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel2_row2" class="row_heading level2 row2" >wiki.en</th>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel3_row2" class="row_heading level3 row2" >threecosmul</th>
#         <td id="T_29eccd56_4771_11e8_885e_16909875b9derow2_col0" class="data row2 col0" >0.0669388</td>
#     </tr>    <tr>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel2_row3" class="row_heading level2 row3" >crawl-300d-2M</th>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel3_row3" class="row_heading level3 row3" >threecosmul</th>
#         <td id="T_29eccd56_4771_11e8_885e_16909875b9derow3_col0" class="data row3 col0" >0.0559184</td>
#     </tr>    <tr>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel2_row4" class="row_heading level2 row4" >wiki.en</th>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel3_row4" class="row_heading level3 row4" >threecosadd</th>
#         <td id="T_29eccd56_4771_11e8_885e_16909875b9derow4_col0" class="data row4 col0" >0.0428571</td>
#     </tr>    <tr>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel2_row5" class="row_heading level2 row5" >wiki-news-300d-1M</th>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel3_row5" class="row_heading level3 row5" >threecosmul</th>
#         <td id="T_29eccd56_4771_11e8_885e_16909875b9derow5_col0" class="data row5 col0" >0.0289796</td>
#     </tr>    <tr>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel2_row6" class="row_heading level2 row6" >crawl-300d-2M</th>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel3_row6" class="row_heading level3 row6" >threecosadd</th>
#         <td id="T_29eccd56_4771_11e8_885e_16909875b9derow6_col0" class="data row6 col0" >0.0232653</td>
#     </tr>    <tr>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel1_row7" class="row_heading level1 row7" >glove</th>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel2_row7" class="row_heading level2 row7" >glove.42B.300d</th>
#         <th id="T_29eccd56_4771_11e8_885e_16909875b9delevel3
